# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhumika20022/AI-EXTERNSHIP/blob/main/web_scrapping_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached BeautifulSoup-3.2.2.tar.gz (32 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import requests
from bs4 import BeautifulSoup

# %%
req=requests.get("https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwiZntm_1r__AhULyxYFHcItA08YABAAGgJ0bA&ohost=www.google.com&cid=CAESauD2uzePSCMLsy_aHENUjnVF1B-e_JrYrvpp9ZPB8Excgx60MTVg2aeZ0JcjWDpSjnIbY3nefJn7cCpb-40B6PSuBpVwzME0Mi4eahKz_AEqLtsZO1pZ6qUFjGLMt4mHyq6ZDGPvnECDCFQ&sig=AOD64_3K5bRuvgnhKQwdQoKVTyRI1UQKEw&q&adurl&ved=2ahUKEwjl8NG_1r__AhVNpVYBHdgrDJAQ0Qx6BAgGEAE")

# %%
soup=BeautifulSoup(req.content,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://media.geeksforgeeks.org/img-practice/favicon-1600291663.png" rel="icon" type="image/x-icon"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#   <meta charset="utf-8"/>
#   <meta content="programming, coding, online, code online, online judge, practice, run code, test, expected outcome, programming competition, programming contest, online programming, online computer programming" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <title>
#    Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses
#   </title>
#   <meta content="Platform to practice programming problems. Solve company interview questions and improve your coding intellect" name="description"/>
#   <meta content="Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses" property="og:title"/>
# ...

# %%
print(soup.get_text())
# Out:
# Courses GeeksforGeeks | Interactive LIVE and Self-Paced CoursesProblemsCoursesJob-a-ThonMEGAContestsGFG Weekly Coding ContestJob-a-ThonMEGABiWizard School ContestPrepare for GATE 2024All Contest and EventsPOTDSign InProblemsCoursesJob-a-ThonMEGAContestsGFG Weekly Coding ContestJob-a-ThonMEGABiWizard School ContestPrepare for GATE 2024All Contest and EventsPOTDGeeksforGeeks CoursesInteractive LIVE & Self-Paced CoursesA-143, 9th Floor, Sovereign Corporate Tower,Sector-136, Noida, Uttar Pradesh - 201305feedback@geeksforgeeks.orgCompanyAbout UsCareersPrivacy PolicyContact UsTerms of ServiceLearnAlgorithmsData StructuresLanguagesCS SubjectsVideo TutorialsPracticeCoursesCompany-wiseTopic-wiseHow to begin?HackathonContributeWrite an ArticleWrite Interview ExperienceInternshipsVideosTrending NowMega Job-A-Thon: FreshersMega Job-A-Thon: ExperiencedDSA Self PacedJava Backend Development@geeksforgeeks, All rights reserved

# %%
res=soup.title
print(res.prettify())
print(res.get_text())
# Out:
# <title>
#  Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses
# </title>
#
# Courses GeeksforGeeks | Interactive LIVE and Self-Paced Courses
